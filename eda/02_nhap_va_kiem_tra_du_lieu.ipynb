# %% [markdown]
# # Bước 2: Nhập và Kiểm Tra Dữ Liệu
#
# Bước này tập trung vào việc tải dữ liệu và kiểm tra ban đầu.
#
# **Mục tiêu:**
# - Tải dữ liệu không bị lỗi
# - Kiểm tra kích thước (rows, columns)
# - Xác định kiểu dữ liệu
# - Phát hiện lỗi hoặc không nhất quán

# %% [markdown]
# ## 2.1 Import thư viện

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import warnings

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', None)

print("✅ Thư viện đã được import thành công!")
# Out:
# ✅ Thư viện đã được import thành công!

# %% [markdown]
# ## 2.2 Tải dữ liệu

# %%
DATA_PATH = Path("../data/raw/accepted_2007_to_2018Q4.csv")

print("=" * 70)
print("📂 THÔNG TIN FILE")
print("=" * 70)
print(f"Đường dẫn: {DATA_PATH}")
print(f"File tồn tại: {DATA_PATH.exists()}")

# Đọc sample để phân tích (file gốc ~1.6GB)
SAMPLE_SIZE = 50000
df = pd.read_csv(DATA_PATH, nrows=SAMPLE_SIZE, low_memory=False)

print(f"✅ Đã tải thành công {SAMPLE_SIZE:,} dòng!")
# Out:
# ======================================================================
# 📂 THÔNG TIN FILE
# ======================================================================
# Đường dẫn: ../data/raw/accepted_2007_to_2018Q4.csv
# File tồn tại: True
# ✅ Đã tải thành công 50,000 dòng!

# %% [markdown]
# ## 2.3 Kiểm tra kích thước dữ liệu

# %%
print("=" * 70)
print("📐 KÍCH THƯỚC DỮ LIỆU")
print("=" * 70)
print(f"Số hàng: {df.shape[0]:,}")
print(f"Số cột: {df.shape[1]}")
print(f"Tổng số ô (cells): {df.shape[0] * df.shape[1]:,}")
print(f"Bộ nhớ sử dụng: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
# Out:
# ======================================================================
# 📐 KÍCH THƯỚC DỮ LIỆU
# ======================================================================
# Số hàng: 50,000
# Số cột: 151
# Tổng số ô (cells): 7,550,000
# Bộ nhớ sử dụng: 128.05 MB

# %% [markdown]
# ## 2.4 Xem dữ liệu mẫu

# %%
print("=" * 70)
print("👀 5 DÒNG ĐẦU TIÊN")
print("=" * 70)
display(df.head())
# Out:
# ======================================================================
# 👀 5 DÒNG ĐẦU TIÊN
# ======================================================================
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade                    emp_title  \
# 0     13.99       123.03     C        C4                      leadman
# 1     11.99       820.28     C        C1                     Engineer
# 2     10.78       432.66     B        B4                 truck driver
# 3     14.85       829.90     C        C5  Information Systems Officer
# 4     22.45       289.91     F        F1          Contract Specialist
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0  10+ years       MORTGAGE     55000.0        Not Verified  Dec-2015
# 1  10+ years       MORTGAGE     65000.0        Not Verified  Dec-2015
# 2  10+ years       MORTGAGE     63000.0        Not Verified  Dec-2015
# 3  10+ years       MORTGAGE    110000.0     Source Verified  Dec-2015
# 4    3 years       MORTGAGE    104433.0     Source Verified  Dec-2015
#
#   loan_status pymnt_plan                                                url  \
# 0  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 1  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 2  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 3     Current          n  https://lendingclub.com/browse/loanDetail.acti...
# 4  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
#
#   desc             purpose               title zip_code addr_state    dti  \
# 0  NaN  debt_consolidation  Debt consolidation    190xx         PA   5.91
# 1  NaN      small_business            Business    577xx         SD  16.06
# 2  NaN    home_improvement                 NaN    605xx         IL  10.78
# 3  NaN  debt_consolidation  Debt consolidation    076xx         NJ  17.06
# 4  NaN      major_purchase      Major purchase    174xx         PA  25.37
#
#    delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0          0.0         Aug-2003           675.0            679.0
# 1          1.0         Dec-1999           715.0            719.0
# 2          0.0         Aug-2000           695.0            699.0
# 3          0.0         Sep-2008           785.0            789.0
# 4          1.0         Jun-1998           695.0            699.0
#
#    inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# 0             1.0                    30.0                     NaN       7.0
# 1             4.0                     6.0                     NaN      22.0
# 2             0.0                     NaN                     NaN       6.0
# 3             0.0                     NaN                     NaN      13.0
# 4             3.0                    12.0                     NaN      12.0
#
#    pub_rec  revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 0      0.0     2765.0        29.7       13.0                   w       0.00
# 1      0.0    21470.0        19.2       38.0                   w       0.00
# 2      0.0     7869.0        56.2       18.0                   w       0.00
# 3      0.0     7802.0        11.6       17.0                   w   15897.65
# 4      0.0    21929.0        64.5       35.0                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0           0.00   4421.723917          4421.72          3600.00
# 1           0.00  25679.660000         25679.66         24700.00
# 2           0.00  22705.924294         22705.92         20000.00
# 3       15897.65  31464.010000         31464.01         19102.35
# 4           0.00  11740.500000         11740.50         10400.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0         821.72                 0.0         0.0                      0.0
# 1         979.66                 0.0         0.0                      0.0
# 2        2705.92                 0.0         0.0                      0.0
# 3       12361.66                 0.0         0.0                      0.0
# 4        1340.50                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Jan-2019           122.67          NaN           Mar-2019
# 1     Jun-2016           926.35          NaN           Mar-2019
# 2     Jun-2017         15813.30          NaN           Mar-2019
# 3     Feb-2019           829.90     Apr-2019           Mar-2019
# 4     Jul-2016         10128.96          NaN           Mar-2018
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 564.0                560.0                         0.0
# 1                 699.0                695.0                         0.0
# 2                 704.0                700.0                         0.0
# 3                 679.0                675.0                         0.0
# 4                 704.0                700.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                         30.0          1.0       Individual
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0        Joint App
# 3                          NaN          1.0       Individual
# 4                          NaN          1.0       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2           71000.0      13.85              Not Verified             0.0
# 3               NaN        NaN                       NaN             0.0
# 4               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0         722.0     144904.0          2.0          2.0          0.0
# 1           0.0     204396.0          1.0          1.0          0.0
# 2           0.0     189699.0          0.0          1.0          0.0
# 3           0.0     301500.0          1.0          1.0          0.0
# 4           0.0     331730.0          1.0          3.0          0.0
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          1.0                21.0        4981.0     36.0          3.0
# 1          1.0                19.0       18005.0     73.0          2.0
# 2          4.0                19.0       10827.0     73.0          0.0
# 3          1.0                23.0       12609.0     70.0          1.0
# 4          3.0                14.0       73839.0     84.0          4.0
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          3.0       722.0      34.0            9300.0     3.0          1.0
# 1          3.0      6472.0      29.0          111800.0     0.0          0.0
# 2          2.0      2081.0      65.0           14000.0     2.0          5.0
# 3          1.0      6987.0      45.0           67300.0     0.0          1.0
# 4          7.0      9702.0      78.0           34000.0     2.0          1.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           4.0                   4.0      20701.0          1506.0     37.2
# 1           6.0                   4.0       9733.0         57830.0     27.1
# 2           1.0                   6.0      31617.0          2737.0     55.9
# 3           0.0                   2.0      23192.0         54962.0     12.1
# 4           3.0                  10.0      27644.0          4567.0     77.5
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               148.0
# 1                       0.0          0.0               113.0
# 2                       0.0          0.0               125.0
# 3                       0.0          0.0                36.0
# 4                       0.0          0.0               128.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                 128.0                    3.0             3.0       1.0
# 1                 192.0                    2.0             2.0       4.0
# 2                 184.0                   14.0            14.0       5.0
# 3                  87.0                    2.0             2.0       1.0
# 4                 210.0                    4.0             4.0       6.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   4.0                      69.0                    4.0
# 1                   2.0                       NaN                    0.0
# 2                 101.0                       NaN                   10.0
# 3                   2.0                       NaN                    NaN
# 4                   4.0                      12.0                    1.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                            69.0                    2.0             2.0
# 1                             6.0                    0.0             5.0
# 2                             NaN                    0.0             2.0
# 3                             NaN                    0.0             4.0
# 4                            12.0                    0.0             4.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              4.0          2.0        5.0        3.0            4.0
# 1              5.0         13.0       17.0        6.0           20.0
# 2              3.0          2.0        4.0        6.0            4.0
# 3              5.0          8.0       10.0        2.0           10.0
# 4              6.0          5.0        9.0       10.0            7.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            9.0                  4.0       7.0               0.0
# 1           27.0                  5.0      22.0               0.0
# 2            7.0                  3.0       6.0               0.0
# 3           13.0                  5.0      13.0               0.0
# 4           19.0                  6.0      12.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 3.0            76.9
# 1           0.0                 0.0                 2.0            97.4
# 2           0.0                 0.0                 0.0           100.0
# 3           0.0                 0.0                 1.0           100.0
# 4           0.0                 0.0                 4.0            96.6
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               0.0                   0.0        0.0         178050.0
# 1               7.7                   0.0        0.0         314017.0
# 2              50.0                   0.0        0.0         218418.0
# 3               0.0                   0.0        0.0         381215.0
# 4              60.0                   0.0        0.0         439570.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0             7746.0          2400.0                     13734.0
# 1            39475.0         79300.0                     24667.0
# 2            18696.0          6200.0                     14877.0
# 3            52226.0         62500.0                     18000.0
# 4            95768.0         20300.0                     88097.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#    sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                       NaN                     NaN               NaN
# 1                       NaN                     NaN               NaN
# 2                       NaN                     NaN               NaN
# 3                       NaN                     NaN               NaN
# 4                       NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   hardship_flag hardship_type hardship_reason hardship_status  deferral_term  \
# 0             N           NaN             NaN             NaN            NaN
# 1             N           NaN             NaN             NaN            NaN
# 2             N           NaN             NaN             NaN            NaN
# 3             N           NaN             NaN             NaN            NaN
# 4             N           NaN             NaN             NaN            NaN
#
#    hardship_amount hardship_start_date hardship_end_date  \
# 0              NaN                 NaN               NaN
# 1              NaN                 NaN               NaN
# 2              NaN                 NaN               NaN
# 3              NaN                 NaN               NaN
# 4              NaN                 NaN               NaN
#
#   payment_plan_start_date  hardship_length  hardship_dpd hardship_loan_status  \
# 0                     NaN              NaN           NaN                  NaN
# 1                     NaN              NaN           NaN                  NaN
# 2                     NaN              NaN           NaN                  NaN
# 3                     NaN              NaN           NaN                  NaN
# 4                     NaN              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN                Cash                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %%
print("\n" + "=" * 70)
print("👀 5 DÒNG CUỐI CÙNG")
print("=" * 70)
display(df.tail())
# Out:
# ======================================================================
# 👀 5 DÒNG CUỐI CÙNG
# ======================================================================
#              id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 49995  65753957        NaN    25000.0      25000.0          25000.0
# 49996  65683967        NaN    13000.0      13000.0          13000.0
# 49997  65743096        NaN     7200.0       7200.0           7200.0
# 49998  65252177        NaN     6000.0       6000.0           6000.0
# 49999  65603914        NaN    28000.0      28000.0          28000.0
#
#              term  int_rate  installment grade sub_grade  \
# 49995   36 months      6.24       763.28     A        A2
# 49996   36 months      5.32       391.50     A        A1
# 49997   36 months     13.18       243.23     C        C3
# 49998   36 months      8.18       188.52     B        B1
# 49999   36 months      5.32       843.22     A        A1
#
#                            emp_title emp_length home_ownership  annual_inc  \
# 49995  Advanced Software Engineer II    3 years       MORTGAGE     97600.0
# 49996              Sales Engineer II  10+ years       MORTGAGE    100000.0
# 49997              Warehouse Manager    4 years       MORTGAGE     43000.0
# 49998            Tool and Die Maker    < 1 year       MORTGAGE     50000.0
# 49999                            NaN        NaN       MORTGAGE     68000.0
#
#       verification_status   issue_d  loan_status pymnt_plan  \
# 49995            Verified  Nov-2015  Charged Off          n
# 49996     Source Verified  Nov-2015   Fully Paid          n
# 49997     Source Verified  Nov-2015   Fully Paid          n
# 49998        Not Verified  Nov-2015   Fully Paid          n
# 49999        Not Verified  Nov-2015   Fully Paid          n
#
#                                                      url desc  \
# 49995  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 49996  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 49997  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 49998  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 49999  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#                   purpose                    title zip_code addr_state    dti  \
# 49995  debt_consolidation       Debt consolidation    801xx         CO  11.94
# 49996  debt_consolidation       Debt consolidation    282xx         NC   7.61
# 49997         credit_card  Credit card refinancing    159xx         PA  25.09
# 49998         credit_card  Credit card refinancing    440xx         OH  27.39
# 49999  debt_consolidation       Debt consolidation    720xx         AR  15.11
#
#        delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 49995          0.0         Sep-2003           730.0            734.0
# 49996          0.0         Jan-1992           815.0            819.0
# 49997          0.0         Apr-2011           695.0            699.0
# 49998          0.0         Aug-1991           670.0            674.0
# 49999          0.0         Nov-1984           710.0            714.0
#
#        inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 49995             0.0                     NaN                     NaN
# 49996             0.0                     NaN                     NaN
# 49997             0.0                     NaN                     NaN
# 49998             2.0                    28.0                    34.0
# 49999             0.0                     NaN                     NaN
#
#        open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 49995      15.0      0.0    13881.0        59.1       41.0
# 49996       8.0      0.0     9484.0        12.2       20.0
# 49997      11.0      0.0     7970.0        33.6       12.0
# 49998      10.0      2.0     5494.0        39.0       26.0
# 49999      10.0      0.0    18027.0        29.2       22.0
#
#       initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 49995                   w        0.0            0.0   5321.290000
# 49996                   w        0.0            0.0  13374.060000
# 49997                   w        0.0            0.0   8194.917878
# 49998                   w        0.0            0.0   6506.102457
# 49999                   w        0.0            0.0  29742.361772
#
#        total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 49995          5321.29          4502.72         818.57                 0.0
# 49996         13374.06         13000.00         374.06                 0.0
# 49997          8194.92          7200.00         994.92                 0.0
# 49998          6506.10          6000.00         506.10                 0.0
# 49999         29742.36         28000.00        1742.36                 0.0
#
#        recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 49995         0.0                      0.0     Jun-2016           763.28
# 49996         0.0                      0.0     Jun-2016         11408.15
# 49997         0.0                      0.0     Mar-2017          4792.34
# 49998         0.0                      0.0     Feb-2017          3869.55
# 49999         0.0                      0.0     May-2017         15432.45
#
#       next_pymnt_d last_credit_pull_d  last_fico_range_high  \
# 49995          NaN           Dec-2015                 799.0
# 49996          NaN           Jun-2016                 819.0
# 49997          NaN           Mar-2019                 714.0
# 49998          NaN           Aug-2017                 749.0
# 49999          NaN           Jun-2017                 749.0
#
#        last_fico_range_low  collections_12_mths_ex_med  \
# 49995                795.0                         0.0
# 49996                815.0                         0.0
# 49997                710.0                         0.0
# 49998                745.0                         0.0
# 49999                745.0                         0.0
#
#        mths_since_last_major_derog  policy_code application_type  \
# 49995                          NaN          1.0       Individual
# 49996                          NaN          1.0       Individual
# 49997                          NaN          1.0       Individual
# 49998                          NaN          1.0       Individual
# 49999                          NaN          1.0       Individual
#
#        annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 49995               NaN        NaN                       NaN             0.0
# 49996               NaN        NaN                       NaN             0.0
# 49997               NaN        NaN                       NaN             0.0
# 49998               NaN        NaN                       NaN             0.0
# 49999               NaN        NaN                       NaN             0.0
#
#        tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 49995           0.0     301203.0          NaN          NaN          NaN
# 49996           0.0     250537.0          NaN          NaN          NaN
# 49997           0.0      26696.0          NaN          NaN          NaN
# 49998         704.0      23592.0          NaN          NaN          NaN
# 49999        1813.0     174692.0          NaN          NaN          NaN
#
#        open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 49995          NaN                 NaN           NaN      NaN          NaN
# 49996          NaN                 NaN           NaN      NaN          NaN
# 49997          NaN                 NaN           NaN      NaN          NaN
# 49998          NaN                 NaN           NaN      NaN          NaN
# 49999          NaN                 NaN           NaN      NaN          NaN
#
#        open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 49995          NaN         NaN       NaN           23500.0     NaN
# 49996          NaN         NaN       NaN           77900.0     NaN
# 49997          NaN         NaN       NaN           23700.0     NaN
# 49998          NaN         NaN       NaN           14100.0     NaN
# 49999          NaN         NaN       NaN           61800.0     NaN
#
#        total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 49995          NaN           NaN                   3.0      20080.0
# 49996          NaN           NaN                   1.0      31317.0
# 49997          NaN           NaN                   6.0       2670.0
# 49998          NaN           NaN                   2.0       2621.0
# 49999          NaN           NaN                   3.0      17469.0
#
#        bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 49995          7230.0     27.7                       0.0          0.0
# 49996         60416.0     13.6                       0.0          0.0
# 49997          1991.0     76.6                       0.0          0.0
# 49998          6589.0     43.7                       0.0          0.0
# 49999         34149.0     33.7                       0.0          0.0
#
#        mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 49995               146.0                 139.0                   42.0
# 49996               156.0                 286.0                   27.0
# 49997                41.0                  55.0                    4.0
# 49998               123.0                 291.0                   24.0
# 49999               127.0                 372.0                   22.0
#
#        mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 49995            11.0       1.0                 139.0
# 49996             9.0       3.0                  27.0
# 49997             4.0       0.0                   4.0
# 49998             9.0       3.0                  37.0
# 49999             3.0       4.0                  22.0
#
#        mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 49995                       NaN                    NaN
# 49996                       NaN                   10.0
# 49997                       NaN                   10.0
# 49998                       NaN                    3.0
# 49999                       NaN                   10.0
#
#        mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 49995                             NaN                    0.0             1.0
# 49996                             NaN                    0.0             2.0
# 49997                             NaN                    0.0             5.0
# 49998                             NaN                    0.0             1.0
# 49999                             NaN                    0.0             3.0
#
#        num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 49995              4.0          1.0        1.0       32.0            5.0
# 49996              2.0          4.0        7.0        5.0            6.0
# 49997              6.0          6.0        6.0        1.0           10.0
# 49998              2.0          2.0        8.0        6.0            6.0
# 49999              5.0          5.0        9.0        5.0            7.0
#
#        num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 49995            8.0                  4.0      15.0               0.0
# 49996           12.0                  2.0       8.0               0.0
# 49997           11.0                  6.0      11.0               0.0
# 49998           16.0                  3.0       9.0               0.0
# 49999           13.0                  5.0      10.0               0.0
#
#        num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 49995           0.0                 0.0                 1.0           100.0
# 49996           0.0                 0.0                 1.0           100.0
# 49997           0.0                 0.0                 4.0           100.0
# 49998           0.0                 0.0                 1.0            95.0
# 49999           0.0                 0.0                 2.0           100.0
#
#        percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 49995               0.0                   0.0        0.0         331304.0
# 49996               0.0                   0.0        0.0         337653.0
# 49997              66.7                   0.0        0.0          59734.0
# 49998               0.0                   1.0        1.0          60068.0
# 49999               0.0                   0.0        0.0         233709.0
#
#        total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 49995            56026.0         10000.0                     51304.0
# 49996            24954.0         69900.0                     28753.0
# 49997            26696.0          8500.0                     36034.0
# 49998            23592.0         11700.0                     45968.0
# 49999            42973.0         51500.0                     38709.0
#
#        revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 49995              NaN                     NaN                      NaN
# 49996              NaN                     NaN                      NaN
# 49997              NaN                     NaN                      NaN
# 49998              NaN                     NaN                      NaN
# 49999              NaN                     NaN                      NaN
#
#        sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 49995                       NaN                     NaN               NaN
# 49996                       NaN                     NaN               NaN
# 49997                       NaN                     NaN               NaN
# 49998                       NaN                     NaN               NaN
# 49999                       NaN                     NaN               NaN
#
#        sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 49995               NaN                 NaN                  NaN
# 49996               NaN                 NaN                  NaN
# 49997               NaN                 NaN                  NaN
# 49998               NaN                 NaN                  NaN
# 49999               NaN                 NaN                  NaN
#
#        sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 49995                    NaN                               NaN
# 49996                    NaN                               NaN
# 49997                    NaN                               NaN
# 49998                    NaN                               NaN
# 49999                    NaN                               NaN
#
#        sec_app_collections_12_mths_ex_med  \
# 49995                                 NaN
# 49996                                 NaN
# 49997                                 NaN
# 49998                                 NaN
# 49999                                 NaN
#
#        sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 49995                                  NaN             N           NaN
# 49996                                  NaN             N           NaN
# 49997                                  NaN             N           NaN
# 49998                                  NaN             N           NaN
# 49999                                  NaN             N           NaN
#
#       hardship_reason hardship_status  deferral_term  hardship_amount  \
# 49995             NaN             NaN            NaN              NaN
# 49996             NaN             NaN            NaN              NaN
# 49997             NaN             NaN            NaN              NaN
# 49998             NaN             NaN            NaN              NaN
# 49999             NaN             NaN            NaN              NaN
#
#       hardship_start_date hardship_end_date payment_plan_start_date  \
# 49995                 NaN               NaN                     NaN
# 49996                 NaN               NaN                     NaN
# 49997                 NaN               NaN                     NaN
# 49998                 NaN               NaN                     NaN
# 49999                 NaN               NaN                     NaN
#
#        hardship_length  hardship_dpd hardship_loan_status  \
# 49995              NaN           NaN                  NaN
# 49996              NaN           NaN                  NaN
# 49997              NaN           NaN                  NaN
# 49998              NaN           NaN                  NaN
# 49999              NaN           NaN                  NaN
#
#        orig_projected_additional_accrued_interest  \
# 49995                                         NaN
# 49996                                         NaN
# 49997                                         NaN
# 49998                                         NaN
# 49999                                         NaN
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 49995                             NaN                           NaN
# 49996                             NaN                           NaN
# 49997                             NaN                           NaN
# 49998                             NaN                           NaN
# 49999                             NaN                           NaN
#
#       disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 49995                Cash                    N                       NaN
# 49996                Cash                    N                       NaN
# 49997                Cash                    N                       NaN
# 49998                Cash                    N                       NaN
# 49999                Cash                    N                       NaN
#
#       settlement_status settlement_date  settlement_amount  \
# 49995               NaN             NaN                NaN
# 49996               NaN             NaN                NaN
# 49997               NaN             NaN                NaN
# 49998               NaN             NaN                NaN
# 49999               NaN             NaN                NaN
#
#        settlement_percentage  settlement_term
# 49995                    NaN              NaN
# 49996                    NaN              NaN
# 49997                    NaN              NaN
# 49998                    NaN              NaN
# 49999                    NaN              NaN

# %% [markdown]
# ## 2.5 Thông tin chi tiết từng cột

# %%
print("=" * 70)
print("ℹ️ THÔNG TIN CHI TIẾT (df.info())")
print("=" * 70)
df.info()
# Out:
# ======================================================================
# ℹ️ THÔNG TIN CHI TIẾT (df.info())
# ======================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 151 entries, id to settlement_term
# dtypes: float64(114), int64(1), object(36)
# memory usage: 57.6+ MB

# %% [markdown]
# ## 2.6 Phân loại kiểu dữ liệu

# %%
print("=" * 70)
print("🔤 PHÂN LOẠI KIỂU DỮ LIỆU")
print("=" * 70)

dtype_summary = df.dtypes.value_counts()
print("\nSố cột theo kiểu dữ liệu:")
for dtype, count in dtype_summary.items():
    print(f"  {dtype}: {count} cột")
# Out:
# ======================================================================
# 🔤 PHÂN LOẠI KIỂU DỮ LIỆU
# ======================================================================
#
# Số cột theo kiểu dữ liệu:
#   float64: 114 cột
#   object: 36 cột
#   int64: 1 cột

# %%
# Liệt kê chi tiết
print("\n--- Cột số (Numerical) ---")
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
print(f"Tổng: {len(num_cols)} cột")
for col in num_cols:
    print(f"  • {col}: {df[col].dtype}")
# Out:
# --- Cột số (Numerical) ---
# Tổng: 115 cột
#   • id: int64
#   • member_id: float64
#   • loan_amnt: float64
#   • funded_amnt: float64
#   • funded_amnt_inv: float64
#   • int_rate: float64
#   • installment: float64
#   • annual_inc: float64
#   • dti: float64
#   • delinq_2yrs: float64
#   • fico_range_low: float64
#   • fico_range_high: float64
#   • inq_last_6mths: float64
#   • mths_since_last_delinq: float64
#   • mths_since_last_record: float64
#   • open_acc: float64
#   • pub_rec: float64
#   • revol_bal: float64
#   • revol_util: float64
#   • total_acc: float64
#   • out_prncp: float64
#   • out_prncp_inv: float64
#   • total_pymnt: float64
#   • total_pymnt_inv: float64
#   • total_rec_prncp: float64
#   • total_rec_int: float64
#   • total_rec_late_fee: float64
#   • recoveries: float64
#   • collection_recovery_fee: float64
#   • last_pymnt_amnt: float64
#   • last_fico_range_high: float64
#   • last_fico_range_low: float64
#   • collections_12_mths_ex_med: float64
#   • mths_since_last_major_derog: float64
#   • policy_code: float64
#   • annual_inc_joint: float64
#   • dti_joint: float64
#   • acc_now_delinq: float64
#   • tot_coll_amt: float64
#   • tot_cur_bal: float64
#   • open_acc_6m: float64
#   • open_act_il: float64
#   • open_il_12m: float64
#   • open_il_24m: float64
#   • mths_since_rcnt_il: float64
#   • total_bal_il: float64
#   • il_util: float64
#   • open_rv_12m: float64
#   • open_rv_24m: float64
#   • max_bal_bc: float64
#   • all_util: float64
#   • total_rev_hi_lim: float64
#   • inq_fi: float64
#   • total_cu_tl: float64
#   • inq_last_12m: float64
#   • acc_open_past_24mths: float64
#   • avg_cur_bal: float64
#   • bc_open_to_buy: float64
#   • bc_util: float64
#   • chargeoff_within_12_mths: float64
#   • delinq_amnt: float64
#   • mo_sin_old_il_acct: float64
#   • mo_sin_old_rev_tl_op: float64
#   • mo_sin_rcnt_rev_tl_op: float64
#   • mo_sin_rcnt_tl: float64
#   • mort_acc: float64
#   • mths_since_recent_bc: float64
#   • mths_since_recent_bc_dlq: float64
#   • mths_since_recent_inq: float64
#   • mths_since_recent_revol_delinq: float64
#   • num_accts_ever_120_pd: float64
#   • num_actv_bc_tl: float64
#   • num_actv_rev_tl: float64
#   • num_bc_sats: float64
#   • num_bc_tl: float64
#   • num_il_tl: float64
#   • num_op_rev_tl: float64
#   • num_rev_accts: float64
#   • num_rev_tl_bal_gt_0: float64
#   • num_sats: float64
#   • num_tl_120dpd_2m: float64
#   • num_tl_30dpd: float64
#   • num_tl_90g_dpd_24m: float64
#   • num_tl_op_past_12m: float64
#   • pct_tl_nvr_dlq: float64
#   • percent_bc_gt_75: float64
#   • pub_rec_bankruptcies: float64
#   • tax_liens: float64
#   • tot_hi_cred_lim: float64
#   • total_bal_ex_mort: float64
#   • total_bc_limit: float64
#   • total_il_high_credit_limit: float64
#   • revol_bal_joint: float64
#   • sec_app_fico_range_low: float64
#   • sec_app_fico_range_high: float64
#   • sec_app_earliest_cr_line: float64
#   • sec_app_inq_last_6mths: float64
#   • sec_app_mort_acc: float64
#   • sec_app_open_acc: float64
#   • sec_app_revol_util: float64
#   • sec_app_open_act_il: float64
#   • sec_app_num_rev_accts: float64
#   • sec_app_chargeoff_within_12_mths: float64
#   • sec_app_collections_12_mths_ex_med: float64
#   • sec_app_mths_since_last_major_derog: float64
#   • deferral_term: float64
#   • hardship_amount: float64
#   • hardship_length: float64
#   • hardship_dpd: float64
#   • orig_projected_additional_accrued_interest: float64
#   • hardship_payoff_balance_amount: float64
#   • hardship_last_payment_amount: float64
#   • settlement_amount: float64
#   • settlement_percentage: float64
#   • settlement_term: float64

# %%
print("\n--- Cột phân loại (Object) ---")
cat_cols = df.select_dtypes(include=['object']).columns.tolist()
print(f"Tổng: {len(cat_cols)} cột")
for col in cat_cols:
    nunique = df[col].nunique()
    print(f"  • {col}: {nunique} giá trị duy nhất")
# Out:
# --- Cột phân loại (Object) ---
# Tổng: 36 cột
#   • term: 2 giá trị duy nhất
#   • grade: 7 giá trị duy nhất
#   • sub_grade: 35 giá trị duy nhất
#   • emp_title: 21288 giá trị duy nhất
#   • emp_length: 11 giá trị duy nhất
#   • home_ownership: 4 giá trị duy nhất
#   • verification_status: 3 giá trị duy nhất
#   • issue_d: 2 giá trị duy nhất
#   • loan_status: 7 giá trị duy nhất
#   • pymnt_plan: 2 giá trị duy nhất
#   • url: 50000 giá trị duy nhất
#   • desc: 3 giá trị duy nhất
#   • purpose: 12 giá trị duy nhất
#   • title: 12 giá trị duy nhất
#   • zip_code: 856 giá trị duy nhất
#   • addr_state: 49 giá trị duy nhất
#   • earliest_cr_line: 605 giá trị duy nhất
#   • initial_list_status: 2 giá trị duy nhất
#   • last_pymnt_d: 40 giá trị duy nhất
#   • next_pymnt_d: 2 giá trị duy nhất
#   • last_credit_pull_d: 41 giá trị duy nhất
#   • application_type: 2 giá trị duy nhất
#   • verification_status_joint: 1 giá trị duy nhất
#   • hardship_flag: 2 giá trị duy nhất
#   • hardship_type: 1 giá trị duy nhất
#   • hardship_reason: 9 giá trị duy nhất
#   • hardship_status: 3 giá trị duy nhất
#   • hardship_start_date: 25 giá trị duy nhất
#   • hardship_end_date: 26 giá trị duy nhất
#   • payment_plan_start_date: 26 giá trị duy nhất
#   • hardship_loan_status: 4 giá trị duy nhất
#   • disbursement_method: 1 giá trị duy nhất
#   • debt_settlement_flag: 2 giá trị duy nhất
#   • debt_settlement_flag_date: 30 giá trị duy nhất
#   • settlement_status: 3 giá trị duy nhất
#   • settlement_date: 35 giá trị duy nhất

# %% [markdown]
# ## 2.7 Số lượng giá trị duy nhất

# %%
print("=" * 70)
print("🔢 SỐ LƯỢNG GIÁ TRỊ DUY NHẤT (df.nunique())")
print("=" * 70)

unique_counts = df.nunique().sort_values()
print(unique_counts)
# Out:
# ======================================================================
# 🔢 SỐ LƯỢNG GIÁ TRỊ DUY NHẤT (df.nunique())
# ======================================================================
# member_id                       0
# sec_app_fico_range_high         0
# sec_app_earliest_cr_line        0
# sec_app_mort_acc                0
# sec_app_open_act_il             0
#                             ...
# tot_cur_bal                 45205
# total_pymnt_inv             45933
# total_pymnt                 47085
# id                          50000
# url                         50000
# Length: 151, dtype: int64

# %% [markdown]
# ## 2.8 Thống kê mô tả cơ bản

# %%
print("=" * 70)
print("📊 THỐNG KÊ MÔ TẢ - BIẾN SỐ (df.describe())")
print("=" * 70)
display(df.describe())
# Out:
# ======================================================================
# 📊 THỐNG KÊ MÔ TẢ - BIẾN SỐ (df.describe())
# ======================================================================
#                  id  member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  5.000000e+04        0.0  50000.000000  50000.000000     50000.000000
# mean   6.670963e+07        NaN  15019.359500  15019.359500     15011.823500
# std    1.942339e+06        NaN   8676.103295   8676.103295      8671.131769
# min    6.702500e+04        NaN   1000.000000   1000.000000       950.000000
# 25%    6.594684e+07        NaN   8000.000000   8000.000000      8000.000000
# 50%    6.654286e+07        NaN  14000.000000  14000.000000     13900.000000
# 75%    6.744762e+07        NaN  20000.000000  20000.000000     20000.000000
# max    6.861706e+07        NaN  35000.000000  35000.000000     35000.000000
#
#            int_rate   installment    annual_inc           dti   delinq_2yrs  \
# count  50000.000000  50000.000000  5.000000e+04  49999.000000  50000.000000
# mean      12.234782    434.098806  7.919317e+04     19.338815      0.345500
# std        4.191338    247.494017  1.013212e+05      9.810057      0.910201
# min        5.320000     14.770000  0.000000e+00      0.000000      0.000000
# 25%        9.170000    255.040000  4.800000e+04     12.680000      0.000000
# 50%       11.990000    378.150000  6.600000e+04     18.820000      0.000000
# 75%       14.480000    573.702500  9.500000e+04     25.615000      0.000000
# max       28.990000   1354.660000  9.000000e+06    999.000000     15.000000
#
#        fico_range_low  fico_range_high  inq_last_6mths  \
# count    50000.000000      50000.00000     50000.00000
# mean       694.447900        698.44806         0.60692
# std         30.895838         30.89662         0.89558
# min        660.000000        664.00000         0.00000
# 25%        670.000000        674.00000         0.00000
# 50%        685.000000        689.00000         0.00000
# 75%        710.000000        714.00000         1.00000
# max        845.000000        850.00000         5.00000
#
#        mths_since_last_delinq  mths_since_last_record      open_acc  \
# count            26001.000000             9185.000000  50000.000000
# mean                34.098727               65.605988     12.051420
# std                 21.842735               23.668435      5.709251
# min                  0.000000                0.000000      1.000000
# 25%                 15.000000               51.000000      8.000000
# 50%                 31.000000               67.000000     11.000000
# 75%                 49.000000               81.000000     15.000000
# max                152.000000              120.000000     67.000000
#
#             pub_rec      revol_bal    revol_util     total_acc     out_prncp  \
# count  50000.000000   50000.000000  49976.000000  50000.000000  50000.000000
# mean       0.245820   17602.784540     52.153029     25.398280   1021.762029
# std        0.668522   23428.686322     24.168475     12.112984   3019.594308
# min        0.000000       0.000000      0.000000      4.000000      0.000000
# 25%        0.000000    6240.000000     34.075000     17.000000      0.000000
# 50%        0.000000   11828.000000     52.000000     24.000000      0.000000
# 75%        0.000000   21333.250000     70.500000     32.000000      0.000000
# max       26.000000  898146.000000    145.800000    127.000000  22692.220000
#
#        out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# count   50000.000000  50000.000000     50000.000000     50000.000000
# mean     1021.208037  15021.698061     15014.412010     12018.753392
# std      3017.852427   9720.750566      9715.324571      8335.015859
# min         0.000000      0.000000         0.000000         0.000000
# 25%         0.000000   7421.519536      7417.847500      5643.580000
# 50%         0.000000  12889.827707     12884.435000     10000.000000
# 75%         0.000000  20756.495398     20751.792500     16100.000000
# max     22692.220000  57291.001148     57291.000000     35000.000000
#
#        total_rec_int  total_rec_late_fee    recoveries  \
# count   50000.000000        5.000000e+04  50000.000000
# mean     2771.829157        2.147584e+00    228.967907
# std      2764.458846        1.428387e+01    974.350304
# min         0.000000       -2.000000e-10      0.000000
# 25%       908.290000        0.000000e+00      0.000000
# 50%      1813.185000        0.000000e+00      0.000000
# 75%      3697.142500        0.000000e+00      0.000000
# max     24125.830000        8.868000e+02  33407.160000
#
#        collection_recovery_fee  last_pymnt_amnt  last_fico_range_high  \
# count             50000.000000     50000.000000          50000.000000
# mean                 40.801093      4163.071142            677.351760
# std                 174.823353      6398.504138             79.403782
# min                   0.000000         0.000000              0.000000
# 25%                   0.000000       328.980000            629.000000
# 50%                   0.000000       743.935000            694.000000
# 75%                   0.000000      5802.640000            734.000000
# max                6013.288800     36307.010000            850.000000
#
#        last_fico_range_low  collections_12_mths_ex_med  \
# count           50000.0000                50000.000000
# mean              661.6104                    0.022880
# std               127.1499                    0.164308
# min                 0.0000                    0.000000
# 25%               625.0000                    0.000000
# 50%               690.0000                    0.000000
# 75%               730.0000                    0.000000
# max               845.0000                    5.000000
#
#        mths_since_last_major_derog  policy_code  annual_inc_joint   dti_joint  \
# count                 14779.000000      50000.0        236.000000  235.000000
# mean                     44.315515          1.0     113560.311737   19.329362
# std                      21.413742          0.0      56424.422443    7.579908
# min                       0.000000          1.0      28000.000000    3.000000
# 25%                      27.000000          1.0      77750.000000   13.915000
# 50%                      44.000000          1.0     103000.000000   18.460000
# 75%                      63.000000          1.0     140000.000000   23.920000
# max                     152.000000          1.0     500000.000000   43.860000
#
#        acc_now_delinq   tot_coll_amt   tot_cur_bal   open_acc_6m  \
# count    50000.000000   50000.000000  5.000000e+04  21372.000000
# mean         0.005420     273.449860  1.425531e+05      1.109021
# std          0.076097    2176.026576  1.585250e+05      1.242675
# min          0.000000       0.000000  0.000000e+00      0.000000
# 25%          0.000000       0.000000  3.172950e+04      0.000000
# 50%          0.000000       0.000000  8.224950e+04      1.000000
# 75%          0.000000       0.000000  2.103110e+05      2.000000
# max          2.000000  169257.000000  3.608951e+06     14.000000
#
#         open_act_il   open_il_12m   open_il_24m  mths_since_rcnt_il  \
# count  21372.000000  21372.000000  21372.000000        20810.000000
# mean       2.928832      0.761651      1.674574           20.912686
# std        3.089987      0.996035      1.688725           27.209081
# min        0.000000      0.000000      0.000000            0.000000
# 25%        1.000000      0.000000      0.000000            6.000000
# 50%        2.000000      0.000000      1.000000           12.000000
# 75%        4.000000      1.000000      2.000000           23.000000
# max       40.000000     12.000000     19.000000          363.000000
#
#         total_bal_il       il_util   open_rv_12m   open_rv_24m     max_bal_bc  \
# count   21372.000000  18617.000000  21372.000000  21372.000000   21372.000000
# mean    36552.811389     71.580491      1.389060      2.975482    5887.979740
# std     43103.833619     23.021964      1.520129      2.631886    5284.701239
# min         0.000000      0.000000      0.000000      0.000000       0.000000
# 25%     10251.500000     59.000000      0.000000      1.000000    2411.000000
# 50%     24684.500000     75.000000      1.000000      2.000000    4483.000000
# 75%     47858.000000     88.000000      2.000000      4.000000    7771.500000
# max    878459.000000    223.000000     22.000000     43.000000  127305.000000
#
#            all_util  total_rev_hi_lim        inq_fi   total_cu_tl  \
# count  21372.000000      50000.000000  21372.000000  21372.000000
# mean      60.881995      34692.979980      0.943945      1.537058
# std       20.013842      34730.582947      1.446872      2.723339
# min        0.000000          0.000000      0.000000      0.000000
# 25%       48.000000      14600.000000      0.000000      0.000000
# 50%       62.000000      25300.000000      0.000000      0.000000
# 75%       75.000000      43200.000000      1.000000      2.000000
# max      151.000000     888800.000000     17.000000     35.000000
#
#        inq_last_12m  acc_open_past_24mths    avg_cur_bal  bc_open_to_buy  \
# count  21372.000000          50000.000000   50000.000000    49547.000000
# mean       2.234091              4.823480   13213.649680    10312.126425
# std        2.480242              3.284639   15846.826397    15645.962281
# min        0.000000              0.000000       0.000000        0.000000
# 25%        0.000000              2.000000    3244.000000     1482.000000
# 50%        2.000000              4.000000    7466.000000     4830.000000
# 75%        3.000000              7.000000   18040.750000    12449.000000
# max       32.000000             64.000000  368205.000000   263953.000000
#
#             bc_util  chargeoff_within_12_mths   delinq_amnt  \
# count  49518.000000              50000.000000  50000.000000
# mean      60.559510                  0.010380     15.006540
# std       27.992154                  0.113281    816.305976
# min        0.000000                  0.000000      0.000000
# 25%       39.100000                  0.000000      0.000000
# 50%       63.400000                  0.000000      0.000000
# 75%       85.200000                  0.000000      0.000000
# max      162.200000                  6.000000  88216.000000
#
#        mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# count        48663.000000          50000.000000           50000.000000
# mean           127.573742            187.097760              13.219600
# std             52.541047             96.716934              17.012239
# min              1.000000              6.000000               0.000000
# 25%            101.000000            120.000000               3.000000
# 50%            130.000000            170.000000               8.000000
# 75%            154.000000            239.000000              16.000000
# max            651.000000            791.000000             270.000000
#
#        mo_sin_rcnt_tl      mort_acc  mths_since_recent_bc  \
# count    50000.000000  50000.000000          49564.000000
# mean         7.598700      1.651440             24.122650
# std          8.872807      1.935237             31.795011
# min          0.000000      0.000000              0.000000
# 25%          3.000000      0.000000              6.000000
# 50%          5.000000      1.000000             13.000000
# 75%         10.000000      3.000000             28.000000
# max        197.000000     25.000000            524.000000
#
#        mths_since_recent_bc_dlq  mths_since_recent_inq  \
# count              12867.000000           44747.000000
# mean                  39.297505               6.547188
# std                   23.042613               5.831184
# min                    0.000000               0.000000
# 25%                   20.000000               2.000000
# 50%                   37.000000               5.000000
# 75%                   59.000000              10.000000
# max                  189.000000              24.000000
#
#        mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# count                    18082.000000           50000.000000    50000.000000
# mean                        35.681396               0.534080        3.738560
# std                         22.683157               1.353556        2.338632
# min                          0.000000               0.000000        0.000000
# 25%                         16.000000               0.000000        2.000000
# 50%                         32.500000               0.000000        3.000000
# 75%                         52.000000               0.000000        5.000000
# max                        153.000000              32.000000       26.000000
#
#        num_actv_rev_tl   num_bc_sats     num_bc_tl     num_il_tl  \
# count     50000.000000  50000.000000  50000.000000  50000.000000
# mean          5.721480      4.864100      8.005840      8.769700
# std           3.384945      3.138373      4.799894      7.530676
# min           0.000000      0.000000      0.000000      0.000000
# 25%           3.000000      3.000000      5.000000      4.000000
# 50%           5.000000      4.000000      7.000000      7.000000
# 75%           7.000000      6.000000     10.000000     12.000000
# max          42.000000     39.000000     65.000000     99.000000
#
#        num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0      num_sats  \
# count   50000.000000   50000.000000         50000.000000  50000.000000
# mean        8.449440      14.705660             5.748820     11.993960
# std         4.741739       8.296358             3.335265      5.689075
# min         0.000000       2.000000             0.000000      1.000000
# 25%         5.000000       9.000000             3.000000      8.000000
# 50%         7.000000      13.000000             5.000000     11.000000
# 75%        11.000000      19.000000             7.000000     15.000000
# max        66.000000     118.000000            43.000000     67.000000
#
#        num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# count      47273.000000   50000.00000        50000.000000        50000.000000
# mean           0.000592       0.00378            0.093100            2.246100
# std            0.025185       0.06392            0.507462            1.906674
# min            0.000000       0.00000            0.000000            0.000000
# 25%            0.000000       0.00000            0.000000            1.000000
# 50%            0.000000       0.00000            0.000000            2.000000
# 75%            0.000000       0.00000            0.000000            3.000000
# max            2.000000       2.00000           14.000000           30.000000
#
#        pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies     tax_liens  \
# count    50000.000000      49504.000000          50000.000000  50000.000000
# mean        93.815292         45.530872              0.139300      0.068040
# std          9.037959         36.310863              0.393826      0.455384
# min         12.500000          0.000000              0.000000      0.000000
# 25%         90.900000         11.100000              0.000000      0.000000
# 50%         97.300000         42.900000              0.000000      0.000000
# 75%        100.000000         75.000000              0.000000      0.000000
# max        100.000000        100.000000              8.000000     25.000000
#
#        tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# count     5.000000e+04       50000.000000    50000.000000
# mean      1.774137e+05       53379.376560    22659.866700
# std       1.772131e+05       48878.265749    22499.381018
# min       2.500000e+03           0.000000        0.000000
# 25%       5.270000e+04       23197.000000     8000.000000
# 50%       1.153010e+05       40636.500000    15600.000000
# 75%       2.554758e+05       67700.000000    29500.000000
# max       4.037303e+06      882172.000000   307500.000000
#
#        total_il_high_credit_limit  revol_bal_joint  sec_app_fico_range_low  \
# count                50000.000000              0.0                     0.0
# mean                 45272.651640              NaN                     NaN
# std                  44713.723334              NaN                     NaN
# min                      0.000000              NaN                     NaN
# 25%                  16664.000000              NaN                     NaN
# 50%                  34673.500000              NaN                     NaN
# 75%                  60522.000000              NaN                     NaN
# max                 975560.000000              NaN                     NaN
#
#        sec_app_fico_range_high  sec_app_earliest_cr_line  \
# count                      0.0                       0.0
# mean                       NaN                       NaN
# std                        NaN                       NaN
# min                        NaN                       NaN
# 25%                        NaN                       NaN
# 50%                        NaN                       NaN
# 75%                        NaN                       NaN
# max                        NaN                       NaN
#
#        sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# count                     0.0               0.0               0.0
# mean                      NaN               NaN               NaN
# std                       NaN               NaN               NaN
# min                       NaN               NaN               NaN
# 25%                       NaN               NaN               NaN
# 50%                       NaN               NaN               NaN
# 75%                       NaN               NaN               NaN
# max                       NaN               NaN               NaN
#
#        sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# count                 0.0                  0.0                    0.0
# mean                  NaN                  NaN                    NaN
# std                   NaN                  NaN                    NaN
# min                   NaN                  NaN                    NaN
# 25%                   NaN                  NaN                    NaN
# 50%                   NaN                  NaN                    NaN
# 75%                   NaN                  NaN                    NaN
# max                   NaN                  NaN                    NaN
#
#        sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# count                               0.0                                 0.0
# mean                                NaN                                 NaN
# std                                 NaN                                 NaN
# min                                 NaN                                 NaN
# 25%                                 NaN                                 NaN
# 50%                                 NaN                                 NaN
# 75%                                 NaN                                 NaN
# max                                 NaN                                 NaN
#
#        sec_app_mths_since_last_major_derog  deferral_term  hardship_amount  \
# count                                  0.0          406.0       406.000000
# mean                                   NaN            3.0       129.777414
# std                                    NaN            0.0       106.781963
# min                                    NaN            3.0         0.640000
# 25%                                    NaN            3.0        47.817500
# 50%                                    NaN            3.0       101.250000
# 75%                                    NaN            3.0       180.137500
# max                                    NaN            3.0       629.700000
#
#        hardship_length  hardship_dpd  \
# count            406.0    406.000000
# mean               3.0     13.975369
# std                0.0      9.983413
# min                3.0      0.000000
# 25%                3.0      6.000000
# 50%                3.0     14.500000
# 75%                3.0     23.000000
# max                3.0     30.000000
#
#        orig_projected_additional_accrued_interest  \
# count                                  325.000000
# mean                                   385.143138
# std                                    320.478947
# min                                      1.920000
# 25%                                    142.440000
# 50%                                    296.610000
# 75%                                    527.370000
# max                                   1889.100000
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# count                      406.000000                    406.000000
# mean                     10431.307488                    191.497044
# std                       6537.325974                    187.127673
# min                         55.730000                      0.050000
# 25%                       5190.170000                     46.355000
# 50%                       9388.780000                    130.515000
# 75%                      15055.480000                    284.637500
# max                      29401.040000                    926.410000
#
#        settlement_amount  settlement_percentage  settlement_term
# count        1537.000000            1537.000000      1537.000000
# mean         5009.780507              47.000150        13.716331
# std          3567.857376               5.367391         7.477062
# min           186.000000              30.000000         0.000000
# 25%          2110.000000              45.000000         8.000000
# 50%          4292.650000              45.000000        14.000000
# 75%          7024.000000              50.000000        18.000000
# max         22000.000000              75.000000        65.000000

# %%
print("\n" + "=" * 70)
print("📊 THỐNG KÊ MÔ TẢ - TẤT CẢ BIẾN")
print("=" * 70)
display(df.describe(include='all'))
# Out:
# ======================================================================
# 📊 THỐNG KÊ MÔ TẢ - TẤT CẢ BIẾN
# ======================================================================
#                   id  member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count   5.000000e+04        0.0  50000.000000  50000.000000     50000.000000
# unique           NaN        NaN           NaN           NaN              NaN
# top              NaN        NaN           NaN           NaN              NaN
# freq             NaN        NaN           NaN           NaN              NaN
# mean    6.670963e+07        NaN  15019.359500  15019.359500     15011.823500
# std     1.942339e+06        NaN   8676.103295   8676.103295      8671.131769
# min     6.702500e+04        NaN   1000.000000   1000.000000       950.000000
# 25%     6.594684e+07        NaN   8000.000000   8000.000000      8000.000000
# 50%     6.654286e+07        NaN  14000.000000  14000.000000     13900.000000
# 75%     6.744762e+07        NaN  20000.000000  20000.000000     20000.000000
# max     6.861706e+07        NaN  35000.000000  35000.000000     35000.000000
#
#               term      int_rate   installment  grade sub_grade emp_title  \
# count        50000  50000.000000  50000.000000  50000     50000     47005
# unique           2           NaN           NaN      7        35     21288
# top      36 months           NaN           NaN      B        C1   Teacher
# freq         34177           NaN           NaN  15264      3309       994
# mean           NaN     12.234782    434.098806    NaN       NaN       NaN
# std            NaN      4.191338    247.494017    NaN       NaN       NaN
# min            NaN      5.320000     14.770000    NaN       NaN       NaN
# 25%            NaN      9.170000    255.040000    NaN       NaN       NaN
# 50%            NaN     11.990000    378.150000    NaN       NaN       NaN
# 75%            NaN     14.480000    573.702500    NaN       NaN       NaN
# max            NaN     28.990000   1354.660000    NaN       NaN       NaN
#
#        emp_length home_ownership    annual_inc verification_status   issue_d  \
# count       47011          50000  5.000000e+04               50000     50000
# unique         11              4           NaN                   3         2
# top     10+ years       MORTGAGE           NaN     Source Verified  Dec-2015
# freq        16712          24586           NaN               20677     43394
# mean          NaN            NaN  7.919317e+04                 NaN       NaN
# std           NaN            NaN  1.013212e+05                 NaN       NaN
# min           NaN            NaN  0.000000e+00                 NaN       NaN
# 25%           NaN            NaN  4.800000e+04                 NaN       NaN
# 50%           NaN            NaN  6.600000e+04                 NaN       NaN
# 75%           NaN            NaN  9.500000e+04                 NaN       NaN
# max           NaN            NaN  9.000000e+06                 NaN       NaN
#
#        loan_status pymnt_plan  \
# count        50000      50000
# unique           7          2
# top     Fully Paid          n
# freq         34978      49995
# mean           NaN        NaN
# std            NaN        NaN
# min            NaN        NaN
# 25%            NaN        NaN
# 50%            NaN        NaN
# 75%            NaN        NaN
# max            NaN        NaN
#
#                                                       url  \
# count                                               50000
# unique                                              50000
# top     https://lendingclub.com/browse/loanDetail.acti...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                      desc             purpose  \
# count                                                   3               50000
# unique                                                  3                  12
# top     We knew that using our credit cards to finance...  debt_consolidation
# freq                                                    1               28283
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#                      title zip_code addr_state           dti   delinq_2yrs  \
# count                49868    50000      50000  49999.000000  50000.000000
# unique                  12      856         49           NaN           NaN
# top     Debt consolidation    750xx         CA           NaN           NaN
# freq                 28224      563       6706           NaN           NaN
# mean                   NaN      NaN        NaN     19.338815      0.345500
# std                    NaN      NaN        NaN      9.810057      0.910201
# min                    NaN      NaN        NaN      0.000000      0.000000
# 25%                    NaN      NaN        NaN     12.680000      0.000000
# 50%                    NaN      NaN        NaN     18.820000      0.000000
# 75%                    NaN      NaN        NaN     25.615000      0.000000
# max                    NaN      NaN        NaN    999.000000     15.000000
#
#        earliest_cr_line  fico_range_low  fico_range_high  inq_last_6mths  \
# count             50000    50000.000000      50000.00000     50000.00000
# unique              605             NaN              NaN             NaN
# top            Aug-2002             NaN              NaN             NaN
# freq                387             NaN              NaN             NaN
# mean                NaN      694.447900        698.44806         0.60692
# std                 NaN       30.895838         30.89662         0.89558
# min                 NaN      660.000000        664.00000         0.00000
# 25%                 NaN      670.000000        674.00000         0.00000
# 50%                 NaN      685.000000        689.00000         0.00000
# 75%                 NaN      710.000000        714.00000         1.00000
# max                 NaN      845.000000        850.00000         5.00000
#
#         mths_since_last_delinq  mths_since_last_record      open_acc  \
# count             26001.000000             9185.000000  50000.000000
# unique                     NaN                     NaN           NaN
# top                        NaN                     NaN           NaN
# freq                       NaN                     NaN           NaN
# mean                 34.098727               65.605988     12.051420
# std                  21.842735               23.668435      5.709251
# min                   0.000000                0.000000      1.000000
# 25%                  15.000000               51.000000      8.000000
# 50%                  31.000000               67.000000     11.000000
# 75%                  49.000000               81.000000     15.000000
# max                 152.000000              120.000000     67.000000
#
#              pub_rec      revol_bal    revol_util     total_acc  \
# count   50000.000000   50000.000000  49976.000000  50000.000000
# unique           NaN            NaN           NaN           NaN
# top              NaN            NaN           NaN           NaN
# freq             NaN            NaN           NaN           NaN
# mean        0.245820   17602.784540     52.153029     25.398280
# std         0.668522   23428.686322     24.168475     12.112984
# min         0.000000       0.000000      0.000000      4.000000
# 25%         0.000000    6240.000000     34.075000     17.000000
# 50%         0.000000   11828.000000     52.000000     24.000000
# 75%         0.000000   21333.250000     70.500000     32.000000
# max        26.000000  898146.000000    145.800000    127.000000
#
#        initial_list_status     out_prncp  out_prncp_inv   total_pymnt  \
# count                50000  50000.000000   50000.000000  50000.000000
# unique                   2           NaN            NaN           NaN
# top                      w           NaN            NaN           NaN
# freq                 40914           NaN            NaN           NaN
# mean                   NaN   1021.762029    1021.208037  15021.698061
# std                    NaN   3019.594308    3017.852427   9720.750566
# min                    NaN      0.000000       0.000000      0.000000
# 25%                    NaN      0.000000       0.000000   7421.519536
# 50%                    NaN      0.000000       0.000000  12889.827707
# 75%                    NaN      0.000000       0.000000  20756.495398
# max                    NaN  22692.220000   22692.220000  57291.001148
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# count      50000.000000     50000.000000   50000.000000        5.000000e+04
# unique              NaN              NaN            NaN                 NaN
# top                 NaN              NaN            NaN                 NaN
# freq                NaN              NaN            NaN                 NaN
# mean       15014.412010     12018.753392    2771.829157        2.147584e+00
# std         9715.324571      8335.015859    2764.458846        1.428387e+01
# min            0.000000         0.000000       0.000000       -2.000000e-10
# 25%         7417.847500      5643.580000     908.290000        0.000000e+00
# 50%        12884.435000     10000.000000    1813.185000        0.000000e+00
# 75%        20751.792500     16100.000000    3697.142500        0.000000e+00
# max        57291.000000     35000.000000   24125.830000        8.868000e+02
#
#           recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# count   50000.000000             50000.000000        49966     50000.000000
# unique           NaN                      NaN           40              NaN
# top              NaN                      NaN     Dec-2018              NaN
# freq             NaN                      NaN         6485              NaN
# mean      228.967907                40.801093          NaN      4163.071142
# std       974.350304               174.823353          NaN      6398.504138
# min         0.000000                 0.000000          NaN         0.000000
# 25%         0.000000                 0.000000          NaN       328.980000
# 50%         0.000000                 0.000000          NaN       743.935000
# 75%         0.000000                 0.000000          NaN      5802.640000
# max     33407.160000              6013.288800          NaN     36307.010000
#
#        next_pymnt_d last_credit_pull_d  last_fico_range_high  \
# count          5995              49999          50000.000000
# unique            2                 41                   NaN
# top        Apr-2019           Mar-2019                   NaN
# freq           5990              21853                   NaN
# mean            NaN                NaN            677.351760
# std             NaN                NaN             79.403782
# min             NaN                NaN              0.000000
# 25%             NaN                NaN            629.000000
# 50%             NaN                NaN            694.000000
# 75%             NaN                NaN            734.000000
# max             NaN                NaN            850.000000
#
#         last_fico_range_low  collections_12_mths_ex_med  \
# count            50000.0000                50000.000000
# unique                  NaN                         NaN
# top                     NaN                         NaN
# freq                    NaN                         NaN
# mean               661.6104                    0.022880
# std                127.1499                    0.164308
# min                  0.0000                    0.000000
# 25%                625.0000                    0.000000
# 50%                690.0000                    0.000000
# 75%                730.0000                    0.000000
# max                845.0000                    5.000000
#
#         mths_since_last_major_derog  policy_code application_type  \
# count                  14779.000000      50000.0            50000
# unique                          NaN          NaN                2
# top                             NaN          NaN       Individual
# freq                            NaN          NaN            49764
# mean                      44.315515          1.0              NaN
# std                       21.413742          0.0              NaN
# min                        0.000000          1.0              NaN
# 25%                       27.000000          1.0              NaN
# 50%                       44.000000          1.0              NaN
# 75%                       63.000000          1.0              NaN
# max                      152.000000          1.0              NaN
#
#         annual_inc_joint   dti_joint verification_status_joint  \
# count         236.000000  235.000000                       236
# unique               NaN         NaN                         1
# top                  NaN         NaN              Not Verified
# freq                 NaN         NaN                       236
# mean       113560.311737   19.329362                       NaN
# std         56424.422443    7.579908                       NaN
# min         28000.000000    3.000000                       NaN
# 25%         77750.000000   13.915000                       NaN
# 50%        103000.000000   18.460000                       NaN
# 75%        140000.000000   23.920000                       NaN
# max        500000.000000   43.860000                       NaN
#
#         acc_now_delinq   tot_coll_amt   tot_cur_bal   open_acc_6m  \
# count     50000.000000   50000.000000  5.000000e+04  21372.000000
# unique             NaN            NaN           NaN           NaN
# top                NaN            NaN           NaN           NaN
# freq               NaN            NaN           NaN           NaN
# mean          0.005420     273.449860  1.425531e+05      1.109021
# std           0.076097    2176.026576  1.585250e+05      1.242675
# min           0.000000       0.000000  0.000000e+00      0.000000
# 25%           0.000000       0.000000  3.172950e+04      0.000000
# 50%           0.000000       0.000000  8.224950e+04      1.000000
# 75%           0.000000       0.000000  2.103110e+05      2.000000
# max           2.000000  169257.000000  3.608951e+06     14.000000
#
#          open_act_il   open_il_12m   open_il_24m  mths_since_rcnt_il  \
# count   21372.000000  21372.000000  21372.000000        20810.000000
# unique           NaN           NaN           NaN                 NaN
# top              NaN           NaN           NaN                 NaN
# freq             NaN           NaN           NaN                 NaN
# mean        2.928832      0.761651      1.674574           20.912686
# std         3.089987      0.996035      1.688725           27.209081
# min         0.000000      0.000000      0.000000            0.000000
# 25%         1.000000      0.000000      0.000000            6.000000
# 50%         2.000000      0.000000      1.000000           12.000000
# 75%         4.000000      1.000000      2.000000           23.000000
# max        40.000000     12.000000     19.000000          363.000000
#
#          total_bal_il       il_util   open_rv_12m   open_rv_24m  \
# count    21372.000000  18617.000000  21372.000000  21372.000000
# unique            NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN
# mean     36552.811389     71.580491      1.389060      2.975482
# std      43103.833619     23.021964      1.520129      2.631886
# min          0.000000      0.000000      0.000000      0.000000
# 25%      10251.500000     59.000000      0.000000      1.000000
# 50%      24684.500000     75.000000      1.000000      2.000000
# 75%      47858.000000     88.000000      2.000000      4.000000
# max     878459.000000    223.000000     22.000000     43.000000
#
#            max_bal_bc      all_util  total_rev_hi_lim        inq_fi  \
# count    21372.000000  21372.000000      50000.000000  21372.000000
# unique            NaN           NaN               NaN           NaN
# top               NaN           NaN               NaN           NaN
# freq              NaN           NaN               NaN           NaN
# mean      5887.979740     60.881995      34692.979980      0.943945
# std       5284.701239     20.013842      34730.582947      1.446872
# min          0.000000      0.000000          0.000000      0.000000
# 25%       2411.000000     48.000000      14600.000000      0.000000
# 50%       4483.000000     62.000000      25300.000000      0.000000
# 75%       7771.500000     75.000000      43200.000000      1.000000
# max     127305.000000    151.000000     888800.000000     17.000000
#
#          total_cu_tl  inq_last_12m  acc_open_past_24mths    avg_cur_bal  \
# count   21372.000000  21372.000000          50000.000000   50000.000000
# unique           NaN           NaN                   NaN            NaN
# top              NaN           NaN                   NaN            NaN
# freq             NaN           NaN                   NaN            NaN
# mean        1.537058      2.234091              4.823480   13213.649680
# std         2.723339      2.480242              3.284639   15846.826397
# min         0.000000      0.000000              0.000000       0.000000
# 25%         0.000000      0.000000              2.000000    3244.000000
# 50%         0.000000      2.000000              4.000000    7466.000000
# 75%         2.000000      3.000000              7.000000   18040.750000
# max        35.000000     32.000000             64.000000  368205.000000
#
#         bc_open_to_buy       bc_util  chargeoff_within_12_mths   delinq_amnt  \
# count     49547.000000  49518.000000              50000.000000  50000.000000
# unique             NaN           NaN                       NaN           NaN
# top                NaN           NaN                       NaN           NaN
# freq               NaN           NaN                       NaN           NaN
# mean      10312.126425     60.559510                  0.010380     15.006540
# std       15645.962281     27.992154                  0.113281    816.305976
# min           0.000000      0.000000                  0.000000      0.000000
# 25%        1482.000000     39.100000                  0.000000      0.000000
# 50%        4830.000000     63.400000                  0.000000      0.000000
# 75%       12449.000000     85.200000                  0.000000      0.000000
# max      263953.000000    162.200000                  6.000000  88216.000000
#
#         mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# count         48663.000000          50000.000000           50000.000000
# unique                 NaN                   NaN                    NaN
# top                    NaN                   NaN                    NaN
# freq                   NaN                   NaN                    NaN
# mean            127.573742            187.097760              13.219600
# std              52.541047             96.716934              17.012239
# min               1.000000              6.000000               0.000000
# 25%             101.000000            120.000000               3.000000
# 50%             130.000000            170.000000               8.000000
# 75%             154.000000            239.000000              16.000000
# max             651.000000            791.000000             270.000000
#
#         mo_sin_rcnt_tl      mort_acc  mths_since_recent_bc  \
# count     50000.000000  50000.000000          49564.000000
# unique             NaN           NaN                   NaN
# top                NaN           NaN                   NaN
# freq               NaN           NaN                   NaN
# mean          7.598700      1.651440             24.122650
# std           8.872807      1.935237             31.795011
# min           0.000000      0.000000              0.000000
# 25%           3.000000      0.000000              6.000000
# 50%           5.000000      1.000000             13.000000
# 75%          10.000000      3.000000             28.000000
# max         197.000000     25.000000            524.000000
#
#         mths_since_recent_bc_dlq  mths_since_recent_inq  \
# count               12867.000000           44747.000000
# unique                       NaN                    NaN
# top                          NaN                    NaN
# freq                         NaN                    NaN
# mean                   39.297505               6.547188
# std                    23.042613               5.831184
# min                     0.000000               0.000000
# 25%                    20.000000               2.000000
# 50%                    37.000000               5.000000
# 75%                    59.000000              10.000000
# max                   189.000000              24.000000
#
#         mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# count                     18082.000000           50000.000000    50000.000000
# unique                             NaN                    NaN             NaN
# top                                NaN                    NaN             NaN
# freq                               NaN                    NaN             NaN
# mean                         35.681396               0.534080        3.738560
# std                          22.683157               1.353556        2.338632
# min                           0.000000               0.000000        0.000000
# 25%                          16.000000               0.000000        2.000000
# 50%                          32.500000               0.000000        3.000000
# 75%                          52.000000               0.000000        5.000000
# max                         153.000000              32.000000       26.000000
#
#         num_actv_rev_tl   num_bc_sats     num_bc_tl     num_il_tl  \
# count      50000.000000  50000.000000  50000.000000  50000.000000
# unique              NaN           NaN           NaN           NaN
# top                 NaN           NaN           NaN           NaN
# freq                NaN           NaN           NaN           NaN
# mean           5.721480      4.864100      8.005840      8.769700
# std            3.384945      3.138373      4.799894      7.530676
# min            0.000000      0.000000      0.000000      0.000000
# 25%            3.000000      3.000000      5.000000      4.000000
# 50%            5.000000      4.000000      7.000000      7.000000
# 75%            7.000000      6.000000     10.000000     12.000000
# max           42.000000     39.000000     65.000000     99.000000
#
#         num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0      num_sats  \
# count    50000.000000   50000.000000         50000.000000  50000.000000
# unique            NaN            NaN                  NaN           NaN
# top               NaN            NaN                  NaN           NaN
# freq              NaN            NaN                  NaN           NaN
# mean         8.449440      14.705660             5.748820     11.993960
# std          4.741739       8.296358             3.335265      5.689075
# min          0.000000       2.000000             0.000000      1.000000
# 25%          5.000000       9.000000             3.000000      8.000000
# 50%          7.000000      13.000000             5.000000     11.000000
# 75%         11.000000      19.000000             7.000000     15.000000
# max         66.000000     118.000000            43.000000     67.000000
#
#         num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# count       47273.000000   50000.00000        50000.000000
# unique               NaN           NaN                 NaN
# top                  NaN           NaN                 NaN
# freq                 NaN           NaN                 NaN
# mean            0.000592       0.00378            0.093100
# std             0.025185       0.06392            0.507462
# min             0.000000       0.00000            0.000000
# 25%             0.000000       0.00000            0.000000
# 50%             0.000000       0.00000            0.000000
# 75%             0.000000       0.00000            0.000000
# max             2.000000       2.00000           14.000000
#
#         num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# count         50000.000000    50000.000000      49504.000000
# unique                 NaN             NaN               NaN
# top                    NaN             NaN               NaN
# freq                   NaN             NaN               NaN
# mean              2.246100       93.815292         45.530872
# std               1.906674        9.037959         36.310863
# min               0.000000       12.500000          0.000000
# 25%               1.000000       90.900000         11.100000
# 50%               2.000000       97.300000         42.900000
# 75%               3.000000      100.000000         75.000000
# max              30.000000      100.000000        100.000000
#
#         pub_rec_bankruptcies     tax_liens  tot_hi_cred_lim  \
# count           50000.000000  50000.000000     5.000000e+04
# unique                   NaN           NaN              NaN
# top                      NaN           NaN              NaN
# freq                     NaN           NaN              NaN
# mean                0.139300      0.068040     1.774137e+05
# std                 0.393826      0.455384     1.772131e+05
# min                 0.000000      0.000000     2.500000e+03
# 25%                 0.000000      0.000000     5.270000e+04
# 50%                 0.000000      0.000000     1.153010e+05
# 75%                 0.000000      0.000000     2.554758e+05
# max                 8.000000     25.000000     4.037303e+06
#
#         total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# count        50000.000000    50000.000000                50000.000000
# unique                NaN             NaN                         NaN
# top                   NaN             NaN                         NaN
# freq                  NaN             NaN                         NaN
# mean         53379.376560    22659.866700                45272.651640
# std          48878.265749    22499.381018                44713.723334
# min              0.000000        0.000000                    0.000000
# 25%          23197.000000     8000.000000                16664.000000
# 50%          40636.500000    15600.000000                34673.500000
# 75%          67700.000000    29500.000000                60522.000000
# max         882172.000000   307500.000000               975560.000000
#
#         revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# count               0.0                     0.0                      0.0
# unique              NaN                     NaN                      NaN
# top                 NaN                     NaN                      NaN
# freq                NaN                     NaN                      NaN
# mean                NaN                     NaN                      NaN
# std                 NaN                     NaN                      NaN
# min                 NaN                     NaN                      NaN
# 25%                 NaN                     NaN                      NaN
# 50%                 NaN                     NaN                      NaN
# 75%                 NaN                     NaN                      NaN
# max                 NaN                     NaN                      NaN
#
#         sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# count                        0.0                     0.0               0.0
# unique                       NaN                     NaN               NaN
# top                          NaN                     NaN               NaN
# freq                         NaN                     NaN               NaN
# mean                         NaN                     NaN               NaN
# std                          NaN                     NaN               NaN
# min                          NaN                     NaN               NaN
# 25%                          NaN                     NaN               NaN
# 50%                          NaN                     NaN               NaN
# 75%                          NaN                     NaN               NaN
# max                          NaN                     NaN               NaN
#
#         sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# count                0.0                 0.0                  0.0
# unique               NaN                 NaN                  NaN
# top                  NaN                 NaN                  NaN
# freq                 NaN                 NaN                  NaN
# mean                 NaN                 NaN                  NaN
# std                  NaN                 NaN                  NaN
# min                  NaN                 NaN                  NaN
# 25%                  NaN                 NaN                  NaN
# 50%                  NaN                 NaN                  NaN
# 75%                  NaN                 NaN                  NaN
# max                  NaN                 NaN                  NaN
#
#         sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# count                     0.0                               0.0
# unique                    NaN                               NaN
# top                       NaN                               NaN
# freq                      NaN                               NaN
# mean                      NaN                               NaN
# std                       NaN                               NaN
# min                       NaN                               NaN
# 25%                       NaN                               NaN
# 50%                       NaN                               NaN
# 75%                       NaN                               NaN
# max                       NaN                               NaN
#
#         sec_app_collections_12_mths_ex_med  \
# count                                  0.0
# unique                                 NaN
# top                                    NaN
# freq                                   NaN
# mean                                   NaN
# std                                    NaN
# min                                    NaN
# 25%                                    NaN
# 50%                                    NaN
# 75%                                    NaN
# max                                    NaN
#
#         sec_app_mths_since_last_major_derog hardship_flag  \
# count                                   0.0         50000
# unique                                  NaN             2
# top                                     NaN             N
# freq                                    NaN         49992
# mean                                    NaN           NaN
# std                                     NaN           NaN
# min                                     NaN           NaN
# 25%                                     NaN           NaN
# 50%                                     NaN           NaN
# 75%                                     NaN           NaN
# max                                     NaN           NaN
#
#                           hardship_type   hardship_reason hardship_status  \
# count                               406               406             406
# unique                                1                 9               3
# top     INTEREST ONLY-3 MONTHS DEFERRAL  NATURAL_DISASTER       COMPLETED
# freq                                406               124             317
# mean                                NaN               NaN             NaN
# std                                 NaN               NaN             NaN
# min                                 NaN               NaN             NaN
# 25%                                 NaN               NaN             NaN
# 50%                                 NaN               NaN             NaN
# 75%                                 NaN               NaN             NaN
# max                                 NaN               NaN             NaN
#
#         deferral_term  hardship_amount hardship_start_date hardship_end_date  \
# count           406.0       406.000000                 406               406
# unique            NaN              NaN                  25                26
# top               NaN              NaN            Sep-2017          Dec-2017
# freq              NaN              NaN                 111                90
# mean              3.0       129.777414                 NaN               NaN
# std               0.0       106.781963                 NaN               NaN
# min               3.0         0.640000                 NaN               NaN
# 25%               3.0        47.817500                 NaN               NaN
# 50%               3.0       101.250000                 NaN               NaN
# 75%               3.0       180.137500                 NaN               NaN
# max               3.0       629.700000                 NaN               NaN
#
#        payment_plan_start_date  hardship_length  hardship_dpd  \
# count                      406            406.0    406.000000
# unique                      26              NaN           NaN
# top                   Oct-2017              NaN           NaN
# freq                        75              NaN           NaN
# mean                       NaN              3.0     13.975369
# std                        NaN              0.0      9.983413
# min                        NaN              3.0      0.000000
# 25%                        NaN              3.0      6.000000
# 50%                        NaN              3.0     14.500000
# 75%                        NaN              3.0     23.000000
# max                        NaN              3.0     30.000000
#
#        hardship_loan_status  orig_projected_additional_accrued_interest  \
# count                   406                                  325.000000
# unique                    4                                         NaN
# top       Late (16-30 days)                                         NaN
# freq                    173                                         NaN
# mean                    NaN                                  385.143138
# std                     NaN                                  320.478947
# min                     NaN                                    1.920000
# 25%                     NaN                                  142.440000
# 50%                     NaN                                  296.610000
# 75%                     NaN                                  527.370000
# max                     NaN                                 1889.100000
#
#         hardship_payoff_balance_amount  hardship_last_payment_amount  \
# count                       406.000000                    406.000000
# unique                             NaN                           NaN
# top                                NaN                           NaN
# freq                               NaN                           NaN
# mean                      10431.307488                    191.497044
# std                        6537.325974                    187.127673
# min                          55.730000                      0.050000
# 25%                        5190.170000                     46.355000
# 50%                        9388.780000                    130.515000
# 75%                       15055.480000                    284.637500
# max                       29401.040000                    926.410000
#
#        disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# count                50000                50000                      1537
# unique                   1                    2                        30
# top                   Cash                    N                  Nov-2018
# freq                 50000                48463                       121
# mean                   NaN                  NaN                       NaN
# std                    NaN                  NaN                       NaN
# min                    NaN                  NaN                       NaN
# 25%                    NaN                  NaN                       NaN
# 50%                    NaN                  NaN                       NaN
# 75%                    NaN                  NaN                       NaN
# max                    NaN                  NaN                       NaN
#
#        settlement_status settlement_date  settlement_amount  \
# count               1537            1537        1537.000000
# unique                 3              35                NaN
# top             COMPLETE        Oct-2017                NaN
# freq                 654             100                NaN
# mean                 NaN             NaN        5009.780507
# std                  NaN             NaN        3567.857376
# min                  NaN             NaN         186.000000
# 25%                  NaN             NaN        2110.000000
# 50%                  NaN             NaN        4292.650000
# 75%                  NaN             NaN        7024.000000
# max                  NaN             NaN       22000.000000
#
#         settlement_percentage  settlement_term
# count             1537.000000      1537.000000
# unique                    NaN              NaN
# top                       NaN              NaN
# freq                      NaN              NaN
# mean                47.000150        13.716331
# std                  5.367391         7.477062
# min                 30.000000         0.000000
# 25%                 45.000000         8.000000
# 50%                 45.000000        14.000000
# 75%                 50.000000        18.000000
# max                 75.000000        65.000000

# %% [markdown]
# ## 2.9 Phát hiện lỗi và không nhất quán

# %%
print("=" * 70)
print("⚠️ PHÁT HIỆN LỖI VÀ KHÔNG NHẤT QUÁN")
print("=" * 70)

# Kiểm tra giá trị âm ở các cột không nên âm
potential_positive_cols = ['loan_amnt', 'funded_amnt', 'annual_inc', 'installment']
print("\n1️⃣ Kiểm tra giá trị âm không hợp lệ:")
for col in potential_positive_cols:
    if col in df.columns:
        negative_count = (df[col] < 0).sum()
        print(f"   {col}: {negative_count} giá trị âm")

# Kiểm tra giá trị ngoài phạm vi cho int_rate
if 'int_rate' in df.columns:
    print("\n2️⃣ Kiểm tra lãi suất (int_rate):")
    print(f"   Min: {df['int_rate'].min()}, Max: {df['int_rate'].max()}")
    out_of_range = ((df['int_rate'] < 0) | (df['int_rate'] > 100)).sum()
    print(f"   Giá trị ngoài [0, 100]: {out_of_range}")

# Kiểm tra term
if 'term' in df.columns:
    print("\n3️⃣ Kiểm tra kỳ hạn (term):")
    print(df['term'].value_counts())
# Out:
# ======================================================================
# ⚠️ PHÁT HIỆN LỖI VÀ KHÔNG NHẤT QUÁN
# ======================================================================
#
# 1️⃣ Kiểm tra giá trị âm không hợp lệ:
#    loan_amnt: 0 giá trị âm
#    funded_amnt: 0 giá trị âm
#    annual_inc: 0 giá trị âm
#    installment: 0 giá trị âm
#
# 2️⃣ Kiểm tra lãi suất (int_rate):
#    Min: 5.32, Max: 28.99
#    Giá trị ngoài [0, 100]: 0
#
# 3️⃣ Kiểm tra kỳ hạn (term):
# term
# 36 months    34177
# 60 months    15823
# Name: count, dtype: int64

# %% [markdown]
# ## 2.10 Tổng kết Bước 2

# %%
print("=" * 70)
print("📋 TỔNG KẾT BƯỚC 2: NHẬP VÀ KIỂM TRA DỮ LIỆU")
print("=" * 70)
print(f"""
✅ ĐÃ HOÀN THÀNH:
   • Tải thành công {SAMPLE_SIZE:,} dòng từ dataset
   • Kích thước: {df.shape[0]:,} hàng × {df.shape[1]} cột
   • Phân loại: {len(num_cols)} biến số, {len(cat_cols)} biến phân loại
   • Bộ nhớ: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB

📊 PHÁT HIỆN BAN ĐẦU:
   • Nhiều cột có giá trị thiếu (sẽ xử lý ở Bước 3)
   • Một số cột date đang ở dạng object
   • Cần kiểm tra thêm về outliers

📝 BƯỚC TIẾP THEO:
   → Bước 3: Xử lý giá trị thiếu (Missing Values)
""")
# Out:
# ======================================================================
# 📋 TỔNG KẾT BƯỚC 2: NHẬP VÀ KIỂM TRA DỮ LIỆU
# ======================================================================
#
# ✅ ĐÃ HOÀN THÀNH:
#    • Tải thành công 50,000 dòng từ dataset
#    • Kích thước: 50,000 hàng × 151 cột
#    • Phân loại: 115 biến số, 36 biến phân loại
#    • Bộ nhớ: 128.05 MB
#
# 📊 PHÁT HIỆN BAN ĐẦU:
#    • Nhiều cột có giá trị thiếu (sẽ xử lý ở Bước 3)
#    • Một số cột date đang ở dạng object
#    • Cần kiểm tra thêm về outliers
#
# 📝 BƯỚC TIẾP THEO:
#    → Bước 3: Xử lý giá trị thiếu (Missing Values)
